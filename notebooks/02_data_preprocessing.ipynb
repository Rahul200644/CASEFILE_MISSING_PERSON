# %% [markdown]
# # Module 2: Data Preprocessing
# Includes coordinate validation, missing value handling, timestamp conversion, and temporal feature extraction.

# %%
import sys
sys.path.append('../')
import pandas as pd
from src.preprocessing import preprocess_gps_data

raw_df = pd.read_csv('../data/raw/gps_trajectories_raw.csv')
clean_df = preprocess_gps_data(raw_df, timestamp_col='datetime')
clean_df.head()
# Out:
#             user_id   latitude   longitude            datetime  hour  day  \
# 0  GEOLIFE_USER_000  39.984702  116.318417 2008-10-23 02:53:04     2   23
# 1  GEOLIFE_USER_000  39.984683  116.318450 2008-10-23 02:53:10     2   23
# 2  GEOLIFE_USER_000  39.984686  116.318417 2008-10-23 02:53:15     2   23
# 3  GEOLIFE_USER_000  39.984688  116.318385 2008-10-23 02:53:20     2   23
# 4  GEOLIFE_USER_000  39.984655  116.318263 2008-10-23 02:53:25     2   23
#
#   day_of_week  weekday  month  is_weekend
# 0    Thursday        3     10           0
# 1    Thursday        3     10           0
# 2    Thursday        3     10           0
# 3    Thursday        3     10           0
# 4    Thursday        3     10           0

# %%
print('Preprocessed Shape:', clean_df.shape)
# Out:
# Preprocessed Shape: (2311807, 10)
