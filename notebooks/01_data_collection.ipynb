# %% [markdown]
# # Module 1: Data Collection & Synthetic Generation
# This notebook demonstrates synthetic GPS trajectory dataset generation and missing person case records creation.

# %%
import sys
sys.path.append('../')
import pandas as pd
import numpy as np
from scripts.generate_and_train import main

print('Running Data Generation Pipeline...')
# Out:
# Running Data Generation Pipeline...

# %%
df_cases = pd.read_csv('../data/synthetic/missing_person_cases.csv')
df_cases.head(10)
# Out:
#        Case_ID   Person_ID Age_Group  Gender  Last_Latitude  Last_Longitude  \
# 0  MP-2026-001  PERSON_001     36–50    Male      45.398293      125.469387
# 1  MP-2026-002  PERSON_002     26–35  Female      23.166469      110.626253
# 2  MP-2026-003  PERSON_003     36–50    Male      45.386764      125.469932
# 3  MP-2026-004  PERSON_004     18–25   Other      23.176430      110.630857
# 4  MP-2026-005  PERSON_005       51+  Female      23.173619      110.615320
# 5  MP-2026-006  PERSON_006       51+    Male      36.678940      113.606940
# 6  MP-2026-007  PERSON_007     36–50    Male      26.404995      101.841822
# 7  MP-2026-008  PERSON_008     36–50  Female      39.958586      116.394962
# 8  MP-2026-009  PERSON_009     26–35    Male      23.174754      110.625356
# 9  MP-2026-010  PERSON_010     36–50   Other      26.400287      101.835363
#
#   Last_Seen_Time        Day Weather Usual_Area  Average_Distance  \
# 0          23:02     Sunday     Fog     Area E              19.4
# 1          15:14   Thursday   Clear     Area A              15.9
# 2          20:01  Wednesday   Clear     Area C               9.4
# 3          21:41  Wednesday    Rain     Area A               1.6
# 4          17:46    Tuesday    Rain     Area D               7.8
# 5          07:23     Monday   Clear     Area E               4.8
# 6          01:32  Wednesday   Clear     Area B               6.9
# 7          22:13  Wednesday     Fog     Area A              10.9
# 8          06:44  Wednesday     Fog     Area A               4.9
# 9          11:43  Wednesday    Rain     Area D              17.8
#
#    Average_Speed Previous_Area  Time_Since_Last_Seen Target_Area
# 0           42.5        Area E                   2.5      Area E
# 1           14.0        Area D                  33.4      Area A
# 2           10.5        Area E                  49.6      Area C
# 3           42.9        Area D                  41.3      Area A
# 4           17.6        Area D                  59.8      Area D
# 5           37.0        Area A                   2.0      Area E
# 6           19.6        Area B                   5.5      Area B
# 7           24.2        Area C                  36.1      Area A
# 8           47.4        Area D                  39.3      Area A
# 9           19.6        Area B                  30.6      Area D
